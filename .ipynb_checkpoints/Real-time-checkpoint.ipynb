# %%
import pandas as pd
import json
import re
import numpy as np
import sqlalchemy
import pymysql
from sqlalchemy import create_engine
import random
from KMeans import KMeans
import numpy as np
import sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
# 讀資料
def read_sql():
    sql = 'select * from table_test'
    engine = create_engine(f'mysql+pymysql://allen:allen0319@192.168.56.161:3306/data?charset=utf8')
    raw_data = pd.read_sql(sql,engine)
    return raw_data,engine

# %%
# 清資料
def wash_data(raw_data):
    df = []
    for i in range(len(raw_data)):
        d = {}
        d['name'] = raw_data['name'][i]
        d['mail'] = raw_data['mail'][i]
        d['gender'] = raw_data['sex'][i]
        d['age'] = raw_data['age'][i]
        d['posture'] = raw_data['posture'][i]
        d['job'] = raw_data['job'][i]
        d['height'] = raw_data['height'][i]
        d['zodiac'] = raw_data['constellation'][i]
        d['personality'] = raw_data['personality'][i]
        d['interest'] = raw_data['interest'][i]
        d['test1'] = raw_data['test1'][i].split(".")[0]
        d['test2'] = raw_data['test2'][i].split(".")[0]
        d['test3'] = raw_data['test3'][i].split(".")[0]
        d['test4_1'] = raw_data['test4_1'][i].split(".")[0]
        d['test4_2'] = raw_data['test4_2'][i].split(".")[0]
        d['test4_3'] = raw_data['test4_3'][i].split(".")[0]
        d['test4_4'] = raw_data['test4_4'][i].split(".")[0]
        d['target_gender'] = raw_data['target_gender'][i]
        age = raw_data['target_age'].split('.')
        d['target_age'] = agec[0][:2]+"~"+c[len(c)-1].replace('沒有限制', '')[-2:]
        d['target_posture'] = raw_data['target_posture'][i]
        height = raw_data['target_height'].split(',')
        d['target_height'] = height[0][:3]+"~"+b[len(b)-1].replace('以上', '')[-3:]
        d['target_personality'] = raw_data['target_personality'][i]
    new_data.append(d)
    new_data = pd.DataFrame(df)
    return new_data

# %%
# 權重設定
def score(new_data):
    personality_score = []
    interest_score = []
    for i in range(len(new_data)):
        p_score = 0
        i_score = 0
        if '外向' in new_data['personality'][i]:
            p_score +=10
        if '樂觀' in new_data['personality'][i]:
            p_score +=7
        if '健談' in new_data['personality'][i]:
            p_score +=9
        if '率直' in new_data['personality'][i]:
            p_score +=7
        if '開朗' in new_data['personality'][i]:
            p_score +=8
        if '不拘小節' in new_data['personality'][i]:
            p_score +=7
        if '幽默' in new_data['personality'][i]:
            p_score +=7    
        if '內向' in new_data['personality'][i]:
            p_score +=1
        if '細心' in new_data['personality'][i]:
            p_score +=2
        if '優柔寡斷' in new_data['personality'][i]:
            personality_score +=2
        if '謹慎' in new_data['personality'][i]:
            p_score +=3
        if '冷靜' in new_data['personality'][i]:
            p_score +=4
        if '文靜' in new_data['personality'][i]:
            p_score +=4
        if '悶騷' in new_data['personality'][i]:
            p_score +=3
            
#  ----------------------------------------- #
        
        if '爬山' in new_data['interest'][i]:
            i_score +=10
        if '球類運動' in new_data['interest'][i]:
            i_score +=10
        if '旅遊' in new_data['interest'][i]:
            i_score +=7
        if '露營' in new_data['interest'][i]:
            i_score +=8
        if '跑步' in new_data['interest'][i]:
            i_score +=9
        if '健身' in new_data['interest'][i]:
            i_score +=8
        if '烹飪' in new_data['interest'][i]:
            i_score +=1
        if '聽音樂看電影' in new_data['interest'][i]:
            i_score +=2
        if '藝文活動' in new_data['interest'][i]:
            i_score +=2
        if '打電動' in new_data['interest'][i]:
            i_score +=2
        if '玩樂器' in new_data['interest'][i]:
            i_score +=2
        if '看漫畫動畫' in new_data['interest'][i]:
            i_score +=1
        if '玩桌遊' in new_data['interest'][i]:
            i_score +=3
        if '小酌' in new_data['interest'][i]:
            i_score +=3  
        interest_score.append(i_score)
        personality_score.append(p_score)
    return personality_score,interest_score

# %%
def score_list(personality_score,interest_score,new_data):
    personality = new_data['personality_score'].values.tolist()
    interest = new_data['interest'].values.tolist()
    new_data['personality_score'] = personality
    new_data['interest_score'] = interest
    renew_data = pd.DataFrame(new_data)
    return renew_data

# %%
def get_center(renew_data):
    a = renew_data.values.tolist()
    w = [a[i][0].split(",") for i in range(len(a))]
    center=[]
    for i in range(len(w)):
        center_group=[]
        for j in range(len(w[i])):
            a=float(w[i][j].replace('[', '').replace(']', ''))
            center_group.append(a)
        center.append(center_group)
    return center

# %%
def get_group(center,engine):
    sql="select * from table1"
    df=pd.read_sql(sql,engine)
    x=df['personality_score'].values.tolist()
    y=df['interest_score'].values.tolist()
    group_list=[]
    for k in range(len(x)):
        point=[]
        for i in range(len(center)):
            answer=math.sqrt((x[k]-center[i][0])**2+(y[k]-center[i][1])**2)
            point.append(answer)
        a=min(point)
        for j in range(len(point)):
            if a == point[j]:
                group = j
                break
        group_list.append(group)
    return group_list

# %%
def to_new_data(group_list,center,engine):    
    sql="select * from table1" 
    df=pd.read_sql(sql,engine)
    new_data=[]
    for k in range(len(df)):
        a={}
        a['name'] = df['name'][k]
        a['mail'] = df['mail'][k]
        a['sex'] = df['sex'][k]
        a['target_gender'] = df['target_gender'][k]
        a['age'] = df['age'][k]
        a['target_age'] = df['target_age'][k]
        a['posture'] = df['posture'][k] 
        a['target_posture'] = df['target_posture'][k] 
        a['height'] = df['height'][k] 
        a['target_height'] = df['target_height'][k]
        a['personality'] = df['personality'][k]
        a['test1'] = df['test1'][k]
        a['test2'] = df['test2'][k]
        a['test3'] = df['test3'][k]
        a['test4_1'] = df['test4_1'][k]
        a['test4_2'] = df['test4_2'][k]
        a['test4_3'] = df['test4_3'][k]
        a['test4_4'] = df['test4_4'][k]
        a['target_personality'] = df['target_personality'][k]                 
        a['personality_score'] = df['personality_score'][k]
        a['interest_score'] = df['interest_score'][k]
        a['mure'] = group_list[k]
        a['center'] = center[group_list[k]]
        new_data.append(a)
    new_data.append(a)
    new_df=pd.DataFrame(new_data)
    new_df.to_csv("new_data1.csv",index=True, index_label="id")
    r_df = pd.read_csv("new_data1.csv", sep=',')
    r_df.to_sql('table2', engine, index= False,if_exists = "replace")

# %%
# 一對多演算法
def algorithm1(engine):
    sql = "select * from table2"
    df = pd.read_sql(sql,engine)
    last_one = df.iloc[-1:]
    r_gender = last_one['r_gender'].values.tolist()[0]
    unacceptable_list = []
    acceptable_list = []
    score_list = []
    for i in range(len(df)):
        score = 0
        if df['gender'].values[i] == r_gender: 
#           身高
            lowest_r_height = last_one['r_height'].values.tolist()[0].replace('以下','').split('~')[0]
            highest_r_height = last_one['r_height'].values.tolist()[0].replace('以下','').split('~')[1]
#           年齡
            lowest_age = last_one['r_age'].values.tolist()[0].split('~')[0]
            highest_age = last_one['r_age'].values.tolist()[0].split('~')[1]
#           體態
            r_posture = last_one['r_posture'].values.tolist()
            if lowest_r_height > df['height'].values[i].replace('以下','').split('~')[0] | highest_r_height < df['height'].values[i].replace('以下','').split('~')[1]:
                unacceptable_list.append(df['mail'][i])
            else:
                score += 15
            if lowest_age > df['age'].values[i].split('~')[0] | highest_age < df['age'].values[i].split('~')[1]:
                unacceptable_list.append(df['mail'][i])
            else:
                score += 15
            if df['posture'].values[i] not in r_posture:
                unacceptable_list.append(df['mail'][i])
            else:
                score += 15
                acceptable_list.append(df['mail'][i])
#           個性
            r_personality = last_one['r_personality'].values.tolist()[0].split(',')
            personality = df['personality'].values[i].tolist()[0].split(',')
            for j in r_personality:
                for k in personality:
                    if k in j:
                        score += 8
#                     else:
#                         score += 0
#           心理測驗
            r_test = last_one['test1'].values.tolist()
            if r_test[0] == df['test1'].values[i][0]:
                score += 8
            r_test2 = last_one['test2'].values.tolist()
            if r_test2[0] == df['test2'].values[i][1]:
                score += 8
            r_test3 = last_one['test3'].values.tolist()
            if r_test3[0] == df['test3'].values[i][2]:
                score += 8
            r_test4 = last_one['test4_1'].values.tolist()
            if r_test4[0] == df['test4_1'].values[i][3]:
                score += 8
            r_test5 = last_one['test4_2'].values.tolist()
            if r_test5[0] == df['test4_2'].values[i][4]:
                score += 8
            r_test6 = last_one['test4_3'].values.tolist()
            if r_test6[0] == df['test4_3'].values[i][5]:
                score += 8
            r_test7 = last_one['test4_4'].values.tolist()
            if r_test7[0] == df['test4_4'].values[i][6]:
                score += 8
            score_list.append(score)
#   找最大值
    f = []
    for i in range(len(acceptable_list)):
        d = {}
        d['mail'] = acceptable_list[i]
        d['score'] = score_list[i]
        f.append(d)
    match = pd.DataFrame(f)
    return match

# %%
try:
    read = read_sql()
    print('1OK')
    wash = wash_data(read)
    print('2OK')
    score = score(wash)
    print('3OK')
    score_list = score_list(score)
    print('4OK')
    center = get_center(score_list)
    print('5OK')
    group = get_group(center)
    print('6OK')
    new_data = to_new_data(group)
    print('7OK')
    algorithm1 = algorithm1(new_data)
    print('8OK')
except Exception as e:
    print(str(e))
# Out:
# (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.56.161' ([Errno 64] Host is down)")
# (Background on this error at: http://sqlalche.me/e/e3q8)
